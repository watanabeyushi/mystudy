# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
data1=pd.read_csv("TS_PDP_0069_20250811.csv")
data2=pd.read_csv("TS_PDP_0070_20250812.csv")
data3=pd.read_csv("TS_PDP_0071_20250813.csv")
data4=pd.read_csv("TS_PDP_0072_20250814.csv")
data5=pd.read_csv("TS_PDP_0073_20250815.csv")
data6=pd.read_csv("TS_PDP_0074_20250816.csv")
data7=pd.read_csv("TS_PDP_0075_20250817.csv")
data8=pd.read_csv("TS_PDP_0076_20250818.csv")
data9=pd.read_csv("TS_PDP_0077_20250819.csv")
data10=pd.read_csv("TS_PDP_0078_20250820.csv")

# %%
dfs = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10]
df = pd.concat(dfs, axis=0, ignore_index=True)
df
# Out:
#                                                   dailyid    year  month  \
# 0       c85f0145504cdc0890aded3a18e48f39df26a721529a70...  2025.0    8.0
# 1       c85f0145504cdc0890aded3a18e48f39df26a721529a70...  2025.0    8.0
# 2       8867847e5b698b442dad1956490dc854ea6c81df7ba561...  2025.0    8.0
# 3       8867847e5b698b442dad1956490dc854ea6c81df7ba561...  2025.0    8.0
# 4       230175bf5369e22e184e6c91919b34ff11b51f479fb3db...  2025.0    8.0
# ...                                                   ...     ...    ...
# 814679  c51ba25a8481096e71c62b2147bba23bb4a915c8bf48e7...  2025.0    8.0
# 814680  6ed57097725044a7a100302e374fedd62d987b8c9c26ad...  2025.0    8.0
# 814681  44b577bf81efaa26e40c59933f60ead45e3d732344dab7...  2025.0    8.0
# 814682  e1aaa23f2536e4f673cf32e8f6ec53af435cfcd91cc821...  2025.0    8.0
# 814683  000c94791462436aa96e79697ea55d421f575063979206...    20.0    NaN
#
#          day  dayofweek  hour  minute   latitude   longitude       os  ...  \
# ...
