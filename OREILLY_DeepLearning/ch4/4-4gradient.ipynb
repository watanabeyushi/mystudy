# %%
import sys ,os
sys.path.append(os.pardir)
import numpy as np
from common.functions import softmax,cross_entropy_error
from common.gradient import numerical_gradient
# Out:
# 'Python 3.10.11' でセルを実行するには、 ipykernel パッケージが必要です。
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Python 環境の作成</a> および必要なパッケージ。
#
# または、次のコマンドを使用して 'ipykernel' をインストールします: 'c:/Users/gnqkn/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
class simpleNet:
    def __init__(self):
        self.W=np.random/randn(2,3)

    def predict(self,x):
        return np.dot(x,self.W)
    
    def loss(self,x,t):
        z=self.predict(x)
        y=softmax(z)
        loss=cross_entropy_error(y,t)

        return loss

# %%
net = simpleNet()
print(net.W)

# %%
x=np.array([0.6,0.9])
p=net.predict(x)
print(p)
print(np.argmax(p))

# %%
t=np.array([0,0,1])
net.loss(x,t)

# %%
def f(W):
    return net.loss(f,net.W)

dW=numerical_gradient(f,net.W)
print(dW)

# %%
f=lambda w: net.loss(x,t)
dW=numerical_gradient(f,net.W)
